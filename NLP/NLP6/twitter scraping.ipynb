# %%
import tweepy
import tweepy.api

# %%
consumer_key = "PE12jwENPbGFtcWcZbjwQNTiX"
consumer_secret = "OcOpgWkc8PWEziqmtt0LaKyAMiEaZAuJpt0T3nPOP9LTSvLyAx"
access_token = "585332053-AlzfrOxVGSuTf4QEhFS2FLA2GcsVwLjARlivdcmB"
access_token_secret = "PQQmrUqD0dkF1qImN6mwik8qGoWIeaPXydPzcseNazXRE"
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(auth = OAuth(config.access_key,
                  config.access_secret,
                  config.consumer_key,
                  config.consumer_secret))

#-----------------------------------------------------------------------
# retrieve global trends.
# other localised trends can be specified by looking up WOE IDs:
#   http://developer.yahoo.com/geo/geoplanet/
# twitter API docs: https://dev.twitter.com/rest/reference/get/trends/place
#-----------------------------------------------------------------------
results = twitter.trends.place(_id = 23424975)

print("UK Trends")

for location in results:
    for trend in location["trends"]:
print(" - %s" % trend["name"])

# %%
api = tweepy.API(auth)

# %%
api.trends_place(1)
# Out:
# [{u'as_of': u'2018-12-07T08:57:47Z',
#   u'created_at': u'2018-12-07T08:50:25Z',
#   u'locations': [{u'name': u'Worldwide', u'woeid': 1}],
#   u'trends': [{u'name': u'#TheGameAwards',
#     u'promoted_content': None,
#     u'query': u'%23TheGameAwards',
#     u'tweet_volume': 460054,
#     u'url': u'http://twitter.com/search?q=%23TheGameAwards'},
#    {u'name': u'Kevin Hart',
#     u'promoted_content': None,
#     u'query': u'%22Kevin+Hart%22',
#     u'tweet_volume': 61303,
#     u'url': u'http://twitter.com/search?q=%22Kevin+Hart%22'},
#    {u'name': u'#FridayFeeling',
#     u'promoted_content': None,
#     u'query': u'%23FridayFeeling',
#     u'tweet_volume': 30618,
#     u'url': u'http://twitter.com/search?q=%23FridayFeeling'},
#    {u'name': u'#Hay\u0131rl\u0131Cumalar',
#     u'promoted_content': None,
#     u'query': u'%23Hay%C4%B1rl%C4%B1Cumalar',
#     u'tweet_volume': 25058,
#     u'url': u'http://twitter.com/search?q=%23Hay%C4%B1rl%C4%B1Cumalar'},
#    {u'name': u'#\u064a\u0648\u0645_\u0627\u0644\u062c\u0645\u0639\u0647',
#     u'promoted_content': None,
#     u'query': u'%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87',
#     u'tweet_volume': 85430,
#     u'url': u'http://twitter.com/search?q=%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87'},
#    {u'name': u'Derrick Henry',
#     u'promoted_content': None,
#     u'query': u'%22Derrick+Henry%22',
#     u'tweet_volume': 108904,
#     u'url': u'http://twitter.com/search?q=%22Derrick+Henry%22'},
#    {u'name': u'#FelizFinde',
#     u'promoted_content': None,
#     u'query': u'%23FelizFinde',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23FelizFinde'},
#    {u'name': u'Smash',
#     u'promoted_content': None,
#     u'query': u'Smash',
#     u'tweet_volume': 453907,
#     u'url': u'http://twitter.com/search?q=Smash'},
#    {u'name': u'\uc774\uc7ac\uc218',
#     u'promoted_content': None,
#     u'query': u'%EC%9D%B4%EC%9E%AC%EC%88%98',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%EC%9D%B4%EC%9E%AC%EC%88%98'},
#    {u'name': u'\u30bd\u30cb\u30fc\u306eiPhone',
#     u'promoted_content': None,
#     u'query': u'%E3%82%BD%E3%83%8B%E3%83%BC%E3%81%AEiPhone',
#     u'tweet_volume': 25072,
#     u'url': u'http://twitter.com/search?q=%E3%82%BD%E3%83%8B%E3%83%BC%E3%81%AEiPhone'},
#    {u'name': u'Mortal Kombat 11',
#     u'promoted_content': None,
#     u'query': u'%22Mortal+Kombat+11%22',
#     u'tweet_volume': 44048,
#     u'url': u'http://twitter.com/search?q=%22Mortal+Kombat+11%22'},
#    {u'name': u'\u30b8\u30e7\u30fc\u30ab\u30fc',
#     u'promoted_content': None,
#     u'query': u'%E3%82%B8%E3%83%A7%E3%83%BC%E3%82%AB%E3%83%BC',
#     u'tweet_volume': 134916,
#     u'url': u'http://twitter.com/search?q=%E3%82%B8%E3%83%A7%E3%83%BC%E3%82%AB%E3%83%BC'},
#    {u'name': u'Persona 5',
#     u'promoted_content': None,
#     u'query': u'%22Persona+5%22',
#     u'tweet_volume': 76938,
#     u'url': u'http://twitter.com/search?q=%22Persona+5%22'},
#    {u'name': u'Luis Valbuena',
#     u'promoted_content': None,
#     u'query': u'%22Luis+Valbuena%22',
#     u'tweet_volume': 15232,
#     u'url': u'http://twitter.com/search?q=%22Luis+Valbuena%22'},
#    {u'name': u'Travis Head',
#     u'promoted_content': None,
#     u'query': u'%22Travis+Head%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Travis+Head%22'},
#    {u'name': u'Punjab Da Captain',
#     u'promoted_content': None,
#     u'query': u'%22Punjab+Da+Captain%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Punjab+Da+Captain%22'},
#    {u'name': u'Frenkie de Jong',
#     u'promoted_content': None,
#     u'query': u'%22Frenkie+de+Jong%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Frenkie+de+Jong%22'},
#    {u'name': u'\u6771\u4eac\u533b\u5927',
#     u'promoted_content': None,
#     u'query': u'%E6%9D%B1%E4%BA%AC%E5%8C%BB%E5%A4%A7',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%E6%9D%B1%E4%BA%AC%E5%8C%BB%E5%A4%A7'},
#    {u'name': u"Bolu Da\u011f\u0131'nda",
#     u'promoted_content': None,
#     u'query': u'%22Bolu+Da%C4%9F%C4%B1%27nda%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Bolu+Da%C4%9F%C4%B1%27nda%22'},
#    {u'name': u'The Outer Worlds',
#     u'promoted_content': None,
#     u'query': u'%22The+Outer+Worlds%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22The+Outer+Worlds%22'},
#    {u'name': u'#ArmedForcesFlagDay',
#     u'promoted_content': None,
#     u'query': u'%23ArmedForcesFlagDay',
#     u'tweet_volume': 21347,
#     u'url': u'http://twitter.com/search?q=%23ArmedForcesFlagDay'},
#    {u'name': u'#\u4eba\u751f\u3067\u6700\u3082\u5927\u5207\u306a\u4e8c\u6587\u5b57',
#     u'promoted_content': None,
#     u'query': u'%23%E4%BA%BA%E7%94%9F%E3%81%A7%E6%9C%80%E3%82%82%E5%A4%A7%E5%88%87%E3%81%AA%E4%BA%8C%E6%96%87%E5%AD%97',
#     u'tweet_volume': 10302,
#     u'url': u'http://twitter.com/search?q=%23%E4%BA%BA%E7%94%9F%E3%81%A7%E6%9C%80%E3%82%82%E5%A4%A7%E5%88%87%E3%81%AA%E4%BA%8C%E6%96%87%E5%AD%97'},
#    {u'name': u'#7dicembre',
#     u'promoted_content': None,
#     u'query': u'%237dicembre',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%237dicembre'},
#    {u'name': u'#MantesLaJolie',
#     u'promoted_content': None,
#     u'query': u'%23MantesLaJolie',
#     u'tweet_volume': 25964,
#     u'url': u'http://twitter.com/search?q=%23MantesLaJolie'},
#    {u'name': u'#VendrediLecture',
#     u'promoted_content': None,
#     u'query': u'%23VendrediLecture',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23VendrediLecture'},
#    {u'name': u'#\u0633\u0639\u0648\u062f\u064a_\u0633\u0627\u062a5',
#     u'promoted_content': None,
#     u'query': u'%23%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%B3%D8%A7%D8%AA5',
#     u'tweet_volume': 20979,
#     u'url': u'http://twitter.com/search?q=%23%D8%B3%D8%B9%D9%88%D8%AF%D9%8A_%D8%B3%D8%A7%D8%AA5'},
#    {u'name': u'#TelanganaElections',
#     u'promoted_content': None,
#     u'query': u'%23TelanganaElections',
#     u'tweet_volume': 16520,
#     u'url': u'http://twitter.com/search?q=%23TelanganaElections'},
#    {u'name': u'#SonchiriyaTeaser',
#     u'promoted_content': None,
#     u'query': u'%23SonchiriyaTeaser',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SonchiriyaTeaser'},
#    {u'name': u'#MamataFearsBJP',
#     u'promoted_content': None,
#     u'query': u'%23MamataFearsBJP',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23MamataFearsBJP'},
#    {u'name': u'#MarjaavaanFirstDayShoot',
#     u'promoted_content': None,
#     u'query': u'%23MarjaavaanFirstDayShoot',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23MarjaavaanFirstDayShoot'},
#    {u'name': u'#cduparteitag',
#     u'promoted_content': None,
#     u'query': u'%23cduparteitag',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23cduparteitag'},
#    {u'name': u'#G\xf6n\xfcll\xfcGen\xe7likG\xfc\xe7l\xfcToplum',
#     u'promoted_content': None,
#     u'query': u'%23G%C3%B6n%C3%BCll%C3%BCGen%C3%A7likG%C3%BC%C3%A7l%C3%BCToplum',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23G%C3%B6n%C3%BCll%C3%BCGen%C3%A7likG%C3%BC%C3%A7l%C3%BCToplum'},
#    {u'name': u'#NitinGadkari',
#     u'promoted_content': None,
#     u'query': u'%23NitinGadkari',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23NitinGadkari'},
#    {u'name': u'#SalaamRockyBhai',
#     u'promoted_content': None,
#     u'query': u'%23SalaamRockyBhai',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SalaamRockyBhai'},
#    {u'name': u'#ToiNoExcusesDay',
#     u'promoted_content': None,
#     u'query': u'%23ToiNoExcusesDay',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23ToiNoExcusesDay'},
#    {u'name': u'#\u062c\u0645\u0639\u0647_\u0645\u0628\u0627\u0631\u0643\u0647',
#     u'promoted_content': None,
#     u'query': u'%23%D8%AC%D9%85%D8%B9%D9%87_%D9%85%D8%A8%D8%A7%D8%B1%D9%83%D9%87',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23%D8%AC%D9%85%D8%B9%D9%87_%D9%85%D8%A8%D8%A7%D8%B1%D9%83%D9%87'},
#    {u'name': u'#PumasvsAmerica',
#     u'promoted_content': None,
#     u'query': u'%23PumasvsAmerica',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23PumasvsAmerica'},
#    {u'name': u'#OurHeroesOurPride',
#     u'promoted_content': None,
#     u'query': u'%23OurHeroesOurPride',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23OurHeroesOurPride'},
#    {u'name': u'#\u3042\u306a\u305f\u306e\u30b9\u30de\u30d6\u30e9\u76f8\u68d2\u8a3a\u65ad',
#     u'promoted_content': None,
#     u'query': u'%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%82%B9%E3%83%9E%E3%83%96%E3%83%A9%E7%9B%B8%E6%A3%92%E8%A8%BA%E6%96%AD',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%82%B9%E3%83%9E%E3%83%96%E3%83%A9%E7%9B%B8%E6%A3%92%E8%A8%BA%E6%96%AD'},
#    {u'name': u'#TheDreadWolfRises',
#     u'promoted_content': None,
#     u'query': u'%23TheDreadWolfRises',
#     u'tweet_volume': 21593,
#     u'url': u'http://twitter.com/search?q=%23TheDreadWolfRises'},
#    {u'name': u'#stoImparando',
#     u'promoted_content': None,
#     u'query': u'%23stoImparando',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23stoImparando'},
#    {u'name': u'#Honor8C',
#     u'promoted_content': None,
#     u'query': u'%23Honor8C',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23Honor8C'},
#    {u'name': u'#JunaidJamshed',
#     u'promoted_content': None,
#     u'query': u'%23JunaidJamshed',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23JunaidJamshed'},
#    {u'name': u'#OTDirecto7DIC',
#     u'promoted_content': None,
#     u'query': u'%23OTDirecto7DIC',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23OTDirecto7DIC'},
#    {u'name': u'#BLACKPINKinJAKARTA',
#     u'promoted_content': None,
#     u'query': u'%23BLACKPINKinJAKARTA',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BLACKPINKinJAKARTA'},
#    {u'name': u'#WSWvCBR',
#     u'promoted_content': None,
#     u'query': u'%23WSWvCBR',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23WSWvCBR'},
#    {u'name': u'#AlexFire',
#     u'promoted_content': None,
#     u'query': u'%23AlexFire',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23AlexFire'},
#    {u'name': u'#SKINS',
#     u'promoted_content': None,
#     u'query': u'%23SKINS',
#     u'tweet_volume': 12336,
#     u'url': u'http://twitter.com/search?q=%23SKINS'},
#    {u'name': u'#NerdenBileceksiniz',
#     u'promoted_content': None,
#     u'query': u'%23NerdenBileceksiniz',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23NerdenBileceksiniz'},
#    {u'name': u'#Be\u015fikta\u015f\u0131nMa\xe7\u0131Var',
#     u'promoted_content': None,
#     u'query': u'%23Be%C5%9Fikta%C5%9F%C4%B1nMa%C3%A7%C4%B1Var',
#     u'tweet_volume': 11062,
#     u'url': u'http://twitter.com/search?q=%23Be%C5%9Fikta%C5%9F%C4%B1nMa%C3%A7%C4%B1Var'}]}]

# %%
public_tweets = api.user_timeline("FIFAcom")
for tweet in public_tweets:
    print(tweet.text)
